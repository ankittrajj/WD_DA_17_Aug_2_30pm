# %%
# Histogram ------> 1,2,3,4
# 34,67,78

import matplotlib.pyplot as plt

# %%
x = ['A','B','C','D']
plt.hist(x)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
# #wap to make a hist of temp vs city.
import numpy as np

# %%
x = np.random.normal(2,3,4)

# %%
x
# Out:
# array([ 2.17549346, -1.52550751,  3.40339219,  2.4630934 ])

# %%
plt.hist(x)
# Out:
# (array([1., 0., 0., 0., 0., 0., 0., 1., 1., 1.]),
#  array([-1.52550751, -1.03261754, -0.53972757, -0.0468376 ,  0.44605237,
#          0.93894234,  1.43183231,  1.92472228,  2.41761225,  2.91050222,
#          3.40339219]),
#  <BarContainer object of 10 artists>)

# %%
x = [45,78,34,45,78,90,121,34,34]
plt.hist(x)
# Out:
# (array([3., 2., 0., 0., 0., 2., 1., 0., 0., 1.]),
#  array([ 34. ,  42.7,  51.4,  60.1,  68.8,  77.5,  86.2,  94.9, 103.6,
#         112.3, 121. ]),
#  <BarContainer object of 10 artists>)

# %%
# subplot ------> 
x = [34,45,56,78,12]
y = [23,89,34,1,-45]
plt.subplot(2,2,1)
plt.plot(x,y)

x = [34,45,56,78,12]
y = [23,89,34,1,-45]
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
1,2,2
