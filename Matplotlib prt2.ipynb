# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#line
# histrogram
# bar,pie,subplot

# line plot -----> representing graphs in the form of lines

# Num/Num
x = [23,45,67,12]
y = [2,4,6,8]

plt.plot(x,y)

# %%
# Num/Categorical

x = [45,56,23,90]
y = ['A','B','C','D']
z = [3,7,11,56]
plt.plot(x,y)
# plt.plot(y,z)

# %%
# Category/Category

x = ['A','B','C']
# y = ['P','Q','R']
z = [True,False,False]
plt.plot(x,z)

# %%
x= np.array([True,True])
y = np.array([False,True])
plt.plot(y,x)

# %%
# barchart---> 

x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.barh(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(16,10))
f = ['NY','Sydeny','London','Paris']
f_t = [45,34,27,36]
x=['Delhi','Jaipur','Noida','Bangalore']
y= [32,30,40,23]
plt.bar(x,y)
plt.bar(f,f_t)
# Out:
# <BarContainer object of 4 artists>

# %%
# pie chart -----> 
a = [45,67,34,29]
myLabel = ['A','B','C','D']
plt.pie(a,labels = myLabel)
# Out:
# ([<matplotlib.patches.Wedge at 0x232c274c700>,
#   <matplotlib.patches.Wedge at 0x232c274cbe0>,
#   <matplotlib.patches.Wedge at 0x232c2769100>,
#   <matplotlib.patches.Wedge at 0x232c27695e0>],
#  [Text(0.7601688777288659, 0.79507438477946, 'A'),
#   Text(-1.043068995306198, 0.34929510593611074, 'B'),
#   Text(-0.08876544246914145, -1.0964126486972219, 'C'),
#   Text(0.9542693369726455, -0.5471471762823854, 'D')])
