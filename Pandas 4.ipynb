# %%
# loc & iloc
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\Indian Startup.csv')

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
#explore the data ......
# observe the data-----> head,tail,sample
df.head()
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
#
#                                         Founder/s  \
# 0                                    Ruchir Arora
# 1                          Anshul Gupta, Amit Raj
# 2                        Nitya, Chaitra Chidanand
# ...

# %%
df.tail()
# Out:
#          Company/Brand  Founded Headquarters         Sector  \
# 1204          HobSpace   2019.0       Mumbai         EdTech
# 1205           DcodeAI   2020.0    New Delhi         EdTech
# 1206  Biocon Biologics   1978.0    Bangalore  BioTechnology
# 1207        KiranaKart   2020.0       Mumbai     E-commerce
# 1208             Meddo   2018.0      Gurgaon     Healthcare
#
#                                            What it does  \
# 1204  HobSpace is a platform for extra-curricular ac...
# 1205       EMPOWER LEARNERS TO BE FUTURE READY USING AI
# 1206  Biocon is a fully integrated pure play biosimi...
# 1207  A better model for instant grocery delivery in...
# 1208   Meddo is an end-to-end medical services provider
#
#                            Founder/s                        Investor/s  \
# 1204    Priya Goel Sheth, Harsh Jain  Siddharth Bhaskar Shah, Upsparks
# 1205  Kartik Sharma, Ashish Aggarwal                           S Chand
# ...

# %%
df.sample(5)
# Out:
#             Company/Brand  Founded Headquarters  \
# 110               VilCart   2017.0    Bangalore
# 829             BlissClub   2020.0    Bangalore
# 278                DeHaat   2012.0     Gurugram
# 2                   Simpl   2015.0    Bangalore
# 841  Asirvad Microfinance   2007.0      Chennai
#
#                                 Sector  \
# 110                             Retail
# 829                            Fashion
# 278  Information Technology & Services
# 2                    Consumer Services
# 841                            FinTech
#
#                                           What it does  \
# 110  Vilcart's motto is sustainable rural developme...
# 829  BlissClub is a community first women’s activew...
# 278  DeHaat™ is one of the fastest growing start-up...
# 2    Simpl empowers merchants to build trusted rela...
# 841  Asirvad Microfinance provides microfinance loa...
#
#                                              Founder/s  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1146 non-null   object
#  7   Amount         1202 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 94.6+ KB

# %%
df.corr()
# Out:
#          Founded
# Founded      1.0

# %%
df.describe()
# Out:
#            Founded
# count  1208.000000
# mean   2016.655629
# std       4.517364
# min    1963.000000
# 25%    2015.000000
# 50%    2018.000000
# 75%    2020.000000
# max    2021.000000

# %%
# 1. Null values
# 2. Amount is categorical instead of numerical.
# 3. Date is in float insted of date time.
# 4. Amount is having irrelavant data -----> $disclosed.

# %%
# loc & iloc
df.columns
# Out:
# Index(['Company/Brand', 'Founded', 'Headquarters', 'Sector', 'What it does',
#        'Founder/s', 'Investor/s', 'Amount', 'Stage', 'Date '],
#       dtype='object')

# %%
df.loc[df['Stage'] == 'Series A']
# Out:
#          Company/Brand  Founded Headquarters                       Sector  \
# 4            PayGlocal   2021.0    Bangalore           Financial Services
# 9           LenDenClub   2015.0       Mumbai           Financial Services
# 10           CometChat   2009.0       Mumbai            Computer Software
# 15            CloudSEK   2015.0    Bangalore  Computer & Network Security
# 17            Trinkerr   2021.0    Bangalore              Capital Markets
# ...                ...      ...          ...                          ...
# 1171  CoinSwitch Kuber   2017.0    Bangalore               Cryptocurrency
# 1177             Ergos   2012.0    Samsitpur                     AgriTech
# 1182           Toothsi   2018.0       Mumbai                   Healthcare
# 1184      Phi Commerce   2015.0         Pune                      FinTech
# 1195               Kyt   2020.0    Bangalore                       EdTech
#
#                                            What it does  \
# ...

# %%
df.loc[df['Sector']=='EdTech'][0:3]
# Out:
#            Company/Brand  Founded Headquarters  Sector  \
# 186               BYJU'S   2011.0    Bangalore  EdTech
# 192  Sunstone Eduversity   2011.0     Gurugram  EdTech
# 254               Questt   2020.0     Gurugram  EdTech
#
#                                           What it does  \
# 186  BYJU’S is India's largest ed-tech company and ...
# 192  Sunstone Eduversity is a one-of-its-kind busin...
# 254  Questt is a Free online homework app that lets...
#
#                             Founder/s  \
# 186  Byju Raveendran, Divya Gokulnath
# 192      Ashish Munjal, Piyush Nangru
# 254      Akhil, Mohsin M, Rohit Pande
#
#                                            Investor/s        Amount     Stage  \
# 186  Oxshott Capital Partners, XN Exponent, Edelweiss  $300,000,000       NaN
# 192                                WestBridge Capital   $28,000,000  Series B
# 254                                   Celesta Capital    $6,750,000  Series A
#
#         Date
# 186  Oct-2021
# ...

# %%
df.loc[0:6]
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
# 5       Curefit   2016.0    Bangalore        Health, Wellness & Fitness
# 6     Pocket FM   2018.0    Bangalore                               OTT
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
# 5                        Tata Digital-backed Curefit
# ...

# %%
# iloc 
df.iloc[0:6]
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
# 5       Curefit   2016.0    Bangalore        Health, Wellness & Fitness
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
# 5                        Tata Digital-backed Curefit
#
#                                         Founder/s  \
# ...

# %%
df.iloc[df['Sector']=='EdTech']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10360/142293616.py in <module>
# ----> 1 df.iloc[df['Sector']=='EdTech']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1550
#    1551         if com.is_bool_indexer(key):
# -> 1552             self._validate_key(key, axis)
#    1553             return self._getbool_axis(key, axis=axis)
#    1554
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
# ...

# %%
df.iloc[0:].count()
# Out:
# Company/Brand    1209
# Founded          1208
# Headquarters     1208
# Sector           1209
# What it does     1209
# Founder/s        1205
# Investor/s       1146
# Amount           1202
# Stage             781
# Date             1209
# dtype: int64

# %%
df.head(6)
# Out:
#   Company/Brand  Founded Headquarters                            Sector  \
# 0  CollegeDekho   2015.0      Gurgaon                        E-learning
# 1          BOX8   2012.0       Mumbai                  Food & Beverages
# 2         Simpl   2015.0    Bangalore                 Consumer Services
# 3   8i Ventures   2018.0       Mumbai  Venture Capital & Private Equity
# 4     PayGlocal   2021.0    Bangalore                Financial Services
# 5       Curefit   2016.0    Bangalore        Health, Wellness & Fitness
#
#                                         What it does  \
# 0  Collegedekho.com is Student’s Partner, Friend ...
# 1                   India's Largest Desi Meals Brand
# 2  Simpl empowers merchants to build trusted rela...
# 3  8i is a Mumbai & Bangalore based early stage f...
# 4  PayGlocal is a FinTech solving for global paym...
# 5                        Tata Digital-backed Curefit
#
#                                         Founder/s  \
# ...

# %%
#when do we use loc & iloc function?

# df.iloc['Founded'][0:8]
df['Sector'].iloc[0:7]
# Out:
# 0                          E-learning
# 1                    Food & Beverages
# 2                   Consumer Services
# 3    Venture Capital & Private Equity
# 4                  Financial Services
# 5          Health, Wellness & Fitness
# 6                                 OTT
# Name: Sector, dtype: object

# %%
df.loc[df['Sector'] == 'EdTech'].iloc[4:9]
# Out:
#        Company/Brand  Founded Headquarters  Sector  \
# 382         Tinkerly   2015.0       Jaipur  EdTech
# 396  Genext Students   2013.0       Mumbai  EdTech
# 401        OckyPocky   2015.0     Gurugram  EdTech
# 409         Codingal   2020.0    Bangalore  EdTech
# 415           Habbit   2020.0    Bangalore  EdTech
#
#                                           What it does  \
# 382  A STEM learning online-offline solutions provi...
# 396  LIVE online classes with expert tutors for K-1...
# 401  OckyPocky is India's 1st interactive English l...
# 409  Codingal is on a mission to inspire school kid...
# 415  Habbit is online learning community for anyone...
#
#                                              Founder/s  \
# 382  O.P. Godara, Vivek Pathak, Kapil Arya, Sharad ...
# 396                    Ali Asgar Kagzi, Piyush Dhanuka
# 401                                       Amit Agrawal
# 409                     Vivek Prakash, Satyam Baranwal
# ...

# %%
# groupby
# merge
# append
# concate
# join

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
df.groupby(['Headquarters','Sector']).mean().iloc[:15]
# Out:
#                                                 Founded
# Headquarters Sector
# Ahmadabad    AR startup                          2016.0
#              Aeorspace                           2017.0
#              Consulting                          2021.0
#              EdTech                              2015.5
#              Rental                              2014.0
# Ahmedabad    Computer Software                   2018.0
#              Consumer Goods                      2014.5
#              Cosmetics                           2019.0
#              Hospital & Health Care              2016.0
#              Housing Marketplace                 2017.0
#              Information Technology & Services   2012.0
#              Legaltech                           2015.0
#              Media                               2018.0
#              Software Startup                    2020.0
# Ambernath    Consumer Goods                      2016.0

# %%
df['Headquarters'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10360/2799248953.py in <module>
# ----> 1 df['Headquarters'].mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
# ...

# %%
# find the sector which is located in gurgaon?
df[df['Headquarters']=='Gurgaon'].groupby('Sector').mean()
# Out:
#                    Founded
# Sector
# B2B Manufacturing   2020.0
# E-learning          2015.0
# EdTech              2019.0
# FinTech             2018.0
# Gaming              2018.0
# Healthcare          2018.0
# Hospitality         2012.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   Headquarters   1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founder/s      1205 non-null   object
#  6   Investor/s     1146 non-null   object
#  7   Amount         1202 non-null   object
#  8   Stage          781 non-null    object
#  9   Date           1209 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 94.6+ KB

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\IPL Matches 2008-2020.csv')

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df[df['city'] == 'Delhi'].groupby('player_of_match').median()
# Out:
#                          id  neutral_venue  result_margin
# player_of_match
# A Mishra           980913.0            0.0            8.0
# A Symonds          419160.0            0.0           11.0
# AB de Villiers    1136605.0            0.0            5.0
# AM Rahane          980965.0            0.0            7.0
# AR Patel           734019.0            0.0            4.0
# AS Rajpoot        1136582.0            0.0            4.0
# BJ Hodge           598071.0            0.0            4.0
# CH Gayle           548372.0            0.0           21.0
# CH Morris          980945.0            0.0            1.0
# CJ Anderson       1082605.0            0.0           51.0
# CR Brathwaite      980951.0            0.0           27.0
# DA Warner          501223.0            0.0           29.0
# DJ Hooda           829715.0            0.0            3.0
# DPMD Jayawardene   336022.0            0.0            6.0
# DR Smith           733981.0            0.0            8.0
# ...

# %%
df[df['city'] == 'Delhi'].groupby('player_of_match').mean()
# Out:
#                             id  neutral_venue  result_margin
# player_of_match
# A Mishra          8.459972e+05            0.0       7.800000
# A Symonds         4.191600e+05            0.0      11.000000
# AB de Villiers    1.136605e+06            0.0       5.000000
# AM Rahane         9.809650e+05            0.0       7.000000
# AR Patel          7.340190e+05            0.0       4.000000
# AS Rajpoot        1.136582e+06            0.0       4.000000
# BJ Hodge          5.980710e+05            0.0       4.000000
# CH Gayle          5.483720e+05            0.0      21.000000
# CH Morris         9.809450e+05            0.0       1.000000
# CJ Anderson       1.082605e+06            0.0      51.000000
# CR Brathwaite     9.809510e+05            0.0      27.000000
# DA Warner         6.337903e+05            0.0      24.333333
# DJ Hooda          8.297150e+05            0.0       3.000000
# DPMD Jayawardene  3.360220e+05            0.0       6.000000
# ...

# %%
df[df['city'] == 'Delhi'].groupby('toss_winner').median()
# Out:
#                                     id  neutral_venue  result_margin
# toss_winner
# Chennai Super Kings           598070.0            0.0           34.0
# Deccan Chargers               460188.0            0.0           11.5
# Delhi Capitals               1176888.5            0.0            6.0
# Delhi Daredevils              548372.0            0.0            8.0
# Kings XI Punjab               573214.0            0.0            5.0
# Kochi Tuskers Kerala          501238.0            0.0            7.0
# Kolkata Knight Riders         980983.0            0.0           24.5
# Mumbai Indians                829747.0            0.0           37.0
# Rajasthan Royals              781845.0            0.0            5.0
# Rising Pune Supergiants       980965.0            0.0            7.0
# Royal Challengers Bangalore   829757.0            0.0           10.0
# Sunrisers Hyderabad           857505.0            0.0            4.5

# %%
df[df['city'] == 'Abu Dhabi'].groupby('toss_winner').median()
# Out:
#                               id  neutral_venue  result_margin
# toss_winner
# Chennai Super Kings    1216492.0            0.0            7.0
# Delhi Capitals         1216529.0            0.0           15.0
# Kings XI Punjab        1216503.0            0.0           48.0
# Kolkata Knight Riders  1216501.0            0.0           10.0
# Mumbai Indians         1216511.0            0.0            8.0
# Rajasthan Royals        729315.0            1.0            6.5
# Sunrisers Hyderabad    1216545.0            0.0            6.5

# %%
# merge
# concate
# append


a = [1,2,3]
b = [9,8,7]
c = a+b
c
# Out:
# [1, 2, 3, 9, 8, 7]

# %%
c.append('Ram')

# %%
c
# Out:
# [1, 2, 3, 9, 8, 7, 'Ram']

# %%
df[['city','toss_winner']].append(pd.DataFrame(['xyz']))
# Out:
#            city                  toss_winner    0
# 0     Bangalore  Royal Challengers Bangalore  NaN
# 1    Chandigarh          Chennai Super Kings  NaN
# 2         Delhi             Rajasthan Royals  NaN
# 3        Mumbai               Mumbai Indians  NaN
# 4       Kolkata              Deccan Chargers  NaN
# ..          ...                          ...  ...
# 812       Dubai               Delhi Capitals  NaN
# 813   Abu Dhabi          Sunrisers Hyderabad  NaN
# 814   Abu Dhabi               Delhi Capitals  NaN
# 815       Dubai               Delhi Capitals  NaN
# 0           NaN                          NaN  xyz
#
# [817 rows x 3 columns]
